# %% [markdown]
# ## `statemodify` Quickstarter Notebook #5 : Sampling Multiple Uncertainties

# %% [markdown]
# In the prior notebooks, we sampled just one type of uncertainty at a time to demonstrate how a single adjustment in the selected input file leads to a verifiable change in output so that we can demonstrate that `statemodify` is working as expected. It is much harder to make sense of the relative importance of uncertain drivers unless we conduct a formal sensitivity analysis, which lies outside of the bounds of this tutorial. However, it is very likely that many of these uncertainties will be present and of interest in any given future for the region. Thus, this notebook is used to demonstrate how to do a Latin hypercube sample simultaneously across multiple uncertainties in a given basin using the `modify_batch()` function.

# %%
import argparse
import logging
import os
import pickle
import subprocess
from string import Template

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import statemodify as stm

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>NOTE</b>: Each simulation in this notebook is run for the length of the historical period (from 1909-2013). If you want to reduce the length of the simulation, navigate to the `.ctl` file and adjust the `iystr` and `iyend` variables. For this notebook, this file is located in: `data/cm2015_StateMod/StateMod/cm2015.ctl`
#
# </div>

# %%
# statemod directory
statemod_dir = "/usr/src/statemodify/statemod_upper_co"

# root directory of statemod data for the target basin
root_dir = os.path.join(statemod_dir, "src", "main", "fortran")

# home directory of notebook instance
# Use pathlib instead of current working directory. cwd would be dir on the left tree when kernel is launched. 
from pathlib import Path
home_dir = Path.home()
base_data_dir = os.environ.get("DATA_DIR", os.path.join(home_dir, "data"))

# path to the statemod executable
statemod_exe = os.path.join(root_dir, "statemod")

# data directory and root name for the target basin
data_dir = os.path.join(base_data_dir, "cm2015_StateMod", "StateMod")

# directory to the target basin input files with root name for the basin
basin_path = os.path.join(data_dir, "cm2015B")

# scenarios output directory
scenarios_dir = os.path.join(data_dir, "scenarios")

# parquet output directory
parquet_dir = os.path.join(data_dir, "parquet")


# path to template file
multi_template_file = os.path.join(base_data_dir, "cm2015B_template_multi.rsp")

# %% [markdown]
# ### Step 1: Creating a Sample Across Multiple Uncertainties

# %% [markdown]
# In this example, we create a global Latin hypercube sample across 3 example uncertainties that we are interested in for the Upper Colorado: evaporation at reservoirs, modification of water rights, and demands. The form of the `modify_batch()` function is similiar to those presented in the last notebooks; however, now, a problem dictionary stores the names of the respective `statemodify` functions (`modify_eva`,  `modify_ddr`, `modify_ddm`) that will now be applied simultaneously. The Latin hypercube sample is conducted with respect to the `bounds` listed and the resulting multipliers or additives are applied to the target IDs listed.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>NOTE</b>: If you are interested in creating an alternative `.ddr` file that does not sample decrees, only adjusts the water rights, then you will need to write `None` in the "bounds" parameter as we do below. If you include bounds, then decrees as well as water rights will be adjusted simultaneously.
#
# </div>

# %%
import statemodify as stm

# variables that apply to multiple functions
output_dir = os.path.join(data_dir, "input_files")
basin_name = "Upper_Colorado"
scenario = "1"
seed_value = 77

# problem dictionary
problem_dict = {
    "n_samples": 1,
    "num_vars": 3,
    "names": ["modify_eva", "modify_ddr", "modify_ddm"],
    "bounds": [[-0.5, 1.0], None, [0.5, 1.0]],
    # additional settings for each function
    "modify_eva": {
        "seed_value": seed_value,
        "output_dir": output_dir,
        "scenario": scenario,
        "basin_name": basin_name,
        "query_field": "id",
        "ids": ["10008", "10009"],
    },
    "modify_ddr": {
        "seed_value": seed_value,
        "output_dir": output_dir,
        "scenario": scenario,
        "basin_name": basin_name,
        "query_field": "id",
        "ids": ["3600507.01", "3600507.02"],
        "admin": [1, None],
        "on_off": [1, 1],
    },
    "modify_ddm": {
        "seed_value": seed_value,
        "output_dir": output_dir,
        "scenario": scenario,
        "basin_name": basin_name,
        "query_field": "id",
        "ids": ["3600507", "3600603"],
    },
}

# run in batch
fn_parameter_dict = stm.modify_batch(problem_dict=problem_dict)
# Out:
# Running modify_eva
# Running modify_ddr
# Running modify_ddm

# %% [markdown]
# ### Step 2: Running a Simulation

# %% [markdown]
# Now that we have developed the samples, we need to adjust our template file to take in the additional uncertainties and then we can run our simulation! Note that in contrast to the other notebooks, we are changing the "EVA", "DDM", and "DDR" entries in the `.rsp` file at the same time, running the simulation, and then extracting the shortages for a specific user (ID: 3601008).

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>NOTE</b> In order to expedite simulations for the Upper Colorado dataset, make sure to turn off "Reoperation" mode. You can do so by opening `/home/jovyan/data/cm2015_StateMod/StateMod/cm2015.ctl`, navigating to the `ireopx` entry and changing the value from "0" to "10".
#
# </div>

# %%
# set realization and sample
realization = 1
sample = np.arange(0, 1, 1)

# read RSP template
with open(multi_template_file) as template_obj:
    # read in file
    template_rsp = Template(template_obj.read())

    for i in sample:
        # create scenario name
        scenario = f"S{i}_{realization}"

        # dictionary holding search keys and replacement values to update the template file
        d = {
            "EVA": f"../../input_files/cm2015B_{scenario}.eva",
            "DDM": f"../../input_files/cm2015B_{scenario}.ddm",
            "DDR": f"../../input_files/cm2015B_{scenario}.ddr",
        }

        # update the template
        new_rsp = template_rsp.safe_substitute(d)

        # construct simulated scenario directory
        simulated_scenario_dir = os.path.join(scenarios_dir, scenario)
        if not os.path.exists(simulated_scenario_dir):
            os.makedirs(simulated_scenario_dir)

        # target rsp file
        rsp_file = os.path.join(simulated_scenario_dir, f"cm2015B_{scenario}.rsp")

        # write updated rsp file
        with open(rsp_file, "w") as f1:
            f1.write(new_rsp)

        # construct simulated basin path
        simulated_basin_path = f"cm2015B_{scenario}"

        # run StateMod
        print(f"Running: {scenario}")
        os.chdir(simulated_scenario_dir)

        subprocess.call([statemod_exe, simulated_basin_path, "-simulate"])

        # Save output to parquet files
        print("creating parquet for " + scenario)

        output_directory = os.path.join(parquet_dir + "/scenario/" + scenario)

        if not os.path.exists(output_directory):
            os.makedirs(output_directory)

        stm.xdd.convert_xdd(
            output_path=output_directory,
            allow_overwrite=False,
            xdd_files=scenarios_dir + "/" + scenario + "/cm2015B_" + scenario + ".xdd",
            id_subset=["3601008"],
            parallel_jobs=2,
        )
# Out:
# Running: S0_1
#   Parse; Command line argument:
#   cm2015B_S0_1 -simulate
# ________________________________________________________________________
#
#         StateMod
#         State of Colorado - Water Supply Planning Model
#
#         Version: 15.00.01
#         Last revision date: 2015/10/28
#
# ________________________________________________________________________
#
#   Opening log file cm2015B_S0_1.log
#
#   Subroutine Execut
#   Subroutine Datinp
#
# ________________________________________________________________________
#   Datinp; Control File (*.ctl)
#
# ________________________________________________________________________
#   Datinp; River Network File (*.rin)
#
# ________________________________________________________________________
#   Datinp; Reservoir Station File (*.res)
#   Subroutine GetRes
#
#   GetRes; Reservoir Station File (*.res)
#
# ________________________________________________________________________
#   Datinp; Diversion Station File (*.dds)
#
# ________________________________________________________________________
#   Datinp; River Station File (*.ris)
#
# ________________________________________________________________________
#   Datinp; Instream Flow Station File (*.ifs)
#
# ________________________________________________________________________
#   Datinp; Well Station File (*.wes)
#
# ________________________________________________________________________
#   Datinp; Plan Station File (*.pln)
#
# ________________________________________________________________________
#   Datinp; River Gage File (*.rig)
#   Subroutine Riginp
#
# ________________________________________________________________________
#   Riginp; Instream Flow Right File (*.ifr)    20    1   98
#
# ________________________________________________________________________
#   Riginp; Reservoir Right File (*.rer)
#
# ________________________________________________________________________
#   Riginp; Direct Diversion Right File (*.ddr)
#
# ________________________________________________________________________
#   Oprinp; Operational Right File (*.opr)
#   Mdainp.for
#
# ________________________________________________________________________
#   Mdainp; Instream flow Demand file - Annual (*.ifa)
#   Subroutine Execut
#
#   Mdainp.for
# + Execut; Year  1908 Month OCT  Day   1 Reoperation     1 Annual Total     0
# + Execut; Year  1908 Month OCT  Day   1 Reoperation     2 Annual Total     1
# + Execut; Year  1908 Month OCT  Day   1 Reoperation     3 Annual Total     2
# + Execut; Year  1908 Month OCT  Day   1 Reoperation     4 Annual Total     3
# + Execut; Year  1908 Month OCT  Day   1 Reoperation     5 Annual Total     4
# + Execut; Year  1908 Month OCT  Day   1 Reoperation     6 Annual Total     5
# + Execut; Year  1908 Month OCT  Day   1 Reoperation     7 Annual Total     6
# + Execut; Year  1908 Month OCT  Day   1 Reoperation     8 Annual Total     7
# + Execut; Year  1908 Month OCT  Day   1 Reoperation     9 Annual Total     8
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    10 Annual Total     9
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    11 Annual Total    10
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    12 Annual Total    11
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    13 Annual Total    12
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    14 Annual Total    13
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    15 Annual Total    14
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    16 Annual Total    15
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    17 Annual Total    16
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    18 Annual Total    17
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    19 Annual Total    18
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    20 Annual Total    19
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    21 Annual Total    20
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    22 Annual Total    21
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    23 Annual Total    22
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    24 Annual Total    23
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    25 Annual Total    24
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    26 Annual Total    25
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    27 Annual Total    26
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    28 Annual Total    27
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    29 Annual Total    28
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    30 Annual Total    29
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    31 Annual Total    30
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    32 Annual Total    31
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    33 Annual Total    32
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    34 Annual Total    33
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    35 Annual Total    34
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    36 Annual Total    35
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    37 Annual Total    36
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    38 Annual Total    37
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    39 Annual Total    38
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    40 Annual Total    39
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    41 Annual Total    40
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    42 Annual Total    41
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    43 Annual Total    42
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    44 Annual Total    43
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    45 Annual Total    44
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    46 Annual Total    45
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    47 Annual Total    46
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    48 Annual Total    47
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    49 Annual Total    48
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    50 Annual Total    49
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    51 Annual Total    50
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    52 Annual Total    51
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    53 Annual Total    52
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    54 Annual Total    53
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    55 Annual Total    54
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    56 Annual Total    55
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    57 Annual Total    56
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    58 Annual Total    57
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    59 Annual Total    58
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    60 Annual Total    59
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    61 Annual Total    60
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    62 Annual Total    61
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    63 Annual Total    62
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    64 Annual Total    63
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    65 Annual Total    64
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    66 Annual Total    65
# + Execut; Year  1908 Month OCT  Day   1 Reoperation    67 Annual Total    66
# + Execut; Year  1908 Month OCT  Day   1 Reoperation
# +   Printing Structure Summary (*.xss)  413 of   443; or      93. % Complete
# +   Printing Structure Summary (*.xss)  414 of   443; or      94. % Complete
# +   Printing Structure Summary (*.xss)  415 of   443; or      94. % Complete
# +   Printing Structure Summary (*.xss)  416 of   443; or      94. % Complete
# +   Printing Structure Summary (*.xss)  417 of   443; or      94. % Complete
# +   Printing Structure Summary (*.xss)  418 of   443; or      95. % Complete
# +   Printing Structure Summary (*.xss)  419 of   443; or      95. % Complete
# +   Printing Structure Summary (*.xss)  420 of   443; or      95. % Complete
# +   Printing Structure Summary (*.xss)  421 of   443; or      95. % Complete
# +   Printing Structure Summary (*.xss)  422 of   443; or      95. % Complete
# +   Printing Structure Summary (*.xss)  423 of   443; or      96. % Complete
# +   Printing Structure Summary (*.xss)  424 of   443; or      96. % Complete
# +   Printing Structure Summary (*.xss)  425 of   443; or      96. % Complete
# +   Printing Structure Summary (*.xss)  426 of   443; or      96. % Complete
# +   Printing Structure Summary (*.xss)  427 of   443; or      97. % Complete
# +   Printing Structure Summary (*.xss)  428 of   443; or      97. % Complete
# +   Printing Structure Summary (*.xss)  429 of   443; or      97. % Complete
# +   Printing Structure Summary (*.xss)  430 of   443; or      97. % Complete
# +   Printing Structure Summary (*.xss)  431 of   443; or      98. % Complete
# +   Printing Structure Summary (*.xss)  432 of   443; or      98. % Complete
# +   Printing Structure Summary (*.xss)  433 of   443; or      98. % Complete
# +   Printing Structure Summary (*.xss)  434 of   443; or      98. % Complete
# +   Printing Structure Summary (*.xss)  435 of   443; or      98. % Complete
# +   Printing Structure Summary (*.xss)  436 of   443; or      99. % Complete
# +   Printing Structure Summary (*.xss)  437 of   443; or      99. % Complete
# +   Printing Structure Summary (*.xss)  438 of   443; or      99. % Complete
# +   Printing Structure Summary (*.xss)  439 of   443; or      99. % Complete
# +   Printing Structure Summary (*.xss)  440 of   443; or     100. % Complete
# +   Printing Structure Summary (*.xss)  441 of   443; or     100. % Complete
# +   Printing Structure Summary (*.xss)  442 of   443; or     100. % Complete
#
# ________________________________________________________________________
#  Subroutine   Outifr
#
# ________________________________________________________________________
#   Subroutine OutPln
#
# ________________________________________________________________________
#   Execut; Successful Run output files are:
#
#   Diversion output:             *.xdd
#   Reservoir output:             *.xre
#   Operating Rule Info:          *.xop
#   Instream Reach Info:          *.xir
#   Structure Summary:            *.xss
#   Call (Control) Summary:       *.xca
#   Plan Output:                  *.xpl
#   Replacement Reesrvoir Output: *.xrp
#
# ________________________________________________________________________
#   Execut; Successful Termination
#   Statem; See detailed messages in file: cm2015B_S0_1.log
#  Stop 0
# creating parquet for S0_1
# 100%|██████████| 1/1 [00:00<00:00,  1.99it/s]

# %% [markdown]
# At the end of the simulation, the output is the file, `cm2015B_S0_1.parquet`, which now contains the shortages for the target ID for the length of the simulation. The user can then proceed to do similiar analyses on water shortages that have been demonstrated in the prior notebooks.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Tip:</b> If you are interested in understanding how to apply `statemodify` functions to your own model, take a look at the source code found in the repository here:
#
#
# <div>
#     1.  <a href="https://github.com/IMMM-SFA/statemodify/blob/main/statemodify/batch.py">modify_batch()</a>
#
# </div>
#
# </div>
